# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt

# %%
data = make_blobs(n_samples=200, n_features=1, centers=4, cluster_std=1.6, random_state=239)
# points = np.random.rand(200)
points = np.sort(data[0]*1000, axis=0, kind='merge')
points
# Out:
# array([[-10676.56171104],
#        [-10245.73146162],
#        [-10153.37418284],
#        [ -9759.12487884],
#        [ -9587.85114017],
#        [ -9569.58258551],
#        [ -8710.00693907],
#        [ -8700.7239082 ],
#        [ -8576.1374698 ],
#        [ -8385.61573721],
#        [ -8216.93574687],
#        [ -8045.28566924],
#        [ -8037.7711824 ],
#        [ -8029.67941943],
#        [ -8011.52063133],
#        [ -7975.18791492],
#        [ -7920.72519042],
#        [ -7904.09327388],
#        [ -7455.04301959],
#        [ -7405.93813994],
#        [ -7285.12109905],
#        [ -7167.25517895],
#        [ -7160.35829457],
#        [ -7114.78856661],
#        [ -7077.11900708],
#        [ -7051.89746193],
#        [ -7025.39688519],
#        [ -7013.60309135],
#        [ -6944.12260856],
#        [ -6857.36797665],
#        [ -6848.54561381],
#        [ -6776.59622826],
#        [ -6725.33490274],
#        [ -6725.27529772],
#        [ -6716.78139291],
# ...

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
# dendrogram = sch.dendrogram(sch.linkage(points, method='ward'))

cls = np.arange(200)
complete_link = np.array([])
dist = np.array([[points[i+1][0] - points[i][0], i] for i in range(points.size - 1)], dtype=int)
print(dist)
dist = dist.sort(axis=0, kind='merge')
dist
# hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'ward')
# y_hc = hc.fit_predict(points)
# Out:
# [[ 430    0]
#  [  92    1]
#  [ 394    2]
#  [ 171    3]
#  [  18    4]
#  [ 859    5]
#  [   9    6]
#  [ 124    7]
#  [ 190    8]
#  [ 168    9]
#  [ 171   10]
#  [   7   11]
#  [   8   12]
#  [  18   13]
#  [  36   14]
#  [  54   15]
#  [  16   16]
#  [ 449   17]
#  [  49   18]
#  [ 120   19]
#  [ 117   20]
#  [   6   21]
#  [  45   22]
#  [  37   23]
#  [  25   24]
#  [  26   25]
#  [  11   26]
#  [  69   27]
#  [  86   28]
#  [   8   29]
#  [  71   30]
#  [  51   31]
#  [   0   32]
#  [   8   33]
#  [  12   34]
#  [   4   35]
#  [  30   36]
#  [   3   37]
#  [  61   38]
#  [ 125   39]
#  [ 154   40]
#  [   5   41]
#  [  39   42]
#  [  35   43]
#  [  14   44]
#  [  44   45]
#  [  14   46]
#  [  59   47]
#  [  89   48]
#  [  10   49]
#  [   0   50]
#  [ 298   51]
#  [ 111   52]
#  [  13   53]
#  [  15   54]
#  [  82   55]
#  [  41   56]
#  [   3   57]
#  [  26   58]
#  [  24   59]
#  [  60   60]
#  [  61   61]
#  [  24   62]
#  [  41   63]
#  [  38   64]
#  [   4   65]
# ...

# %%
plt.figure(figsize=(20,5))
plt.scatter(points[y_hc ==0], np.zeros(len(points[y_hc ==0])), s=20, c='red', marker='x')
plt.scatter(points[y_hc==1], np.zeros(len(points[y_hc ==1])), s=20, c='black', marker='x')
plt.scatter(points[y_hc ==2], np.zeros(len(points[y_hc ==2])), s=20, c='blue', marker='x')
plt.scatter(points[y_hc ==3], np.zeros(len(points[y_hc ==3])), s=20, c='cyan', marker='x')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-e9aed2da6b73> in <module>
# ----> 1 points[0]
#
# TypeError: 'NoneType' object is not subscriptable
